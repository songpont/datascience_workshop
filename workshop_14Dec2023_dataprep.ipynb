# %% [markdown]
# <a href="https://colab.research.google.com/github/songpont/report/blob/master/workshop_14Dec2023_dataprep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pandas

# %%
import pandas as pd
# Specify the path to your file
file_path = '/content/drive/MyDrive/PM_esan/Fire_Source_2012-2023Nov/03_Yearly_ADM_LU/2013_adm_LU.csv' # Change 'your_file.csv' to your file's name

# Read the file into a DataFrame
df1 = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
df1.head()
# Out:
#     latitude   longitude  brightness  scan  track    acq_date  acq_time  \
# 0  16.037905  104.075516      336.31  0.39   0.36  2013/01/20       618
# 1  15.993228  104.105576      335.04  0.39   0.36  2013/02/05       618
# 2  16.053541  104.096535      335.68  0.48   0.40  2013/02/06       600
# 3  16.052341  104.097794      333.97  0.48   0.40  2013/02/06       600
# 4  16.067593  104.087807      335.17  0.49   0.49  2013/02/12       548
#
#   satellite instrument confidence  ...  daynight  type  Year TAM_NAM_T  \
# 0         N      VIIRS          n  ...         D     0  2013  ต.ภูเงิน
# 1         N      VIIRS          n  ...         D     0  2013  ต.ภูเงิน
# 2         N      VIIRS          n  ...         D     0  2013  ต.ภูเงิน
# 3         N      VIIRS          n  ...         D     0  2013  ต.ภูเงิน
# 4         N      VIIRS          n  ...         D     0  2013  ต.ภูเงิน
#
#     AMPHOE_T          AMPHOE_E PROV_NAM_T PROV_NAM_E LUL1_CODE LUL2_CODE
# ...

# %%
df1
# Out:
#         latitude   longitude  brightness  scan  track    acq_date  acq_time  \
# 0      16.037905  104.075516      336.31  0.39   0.36  2013/01/20       618
# 1      15.993228  104.105576      335.04  0.39   0.36  2013/02/05       618
# 2      16.053541  104.096535      335.68  0.48   0.40  2013/02/06       600
# 3      16.052341  104.097794      333.97  0.48   0.40  2013/02/06       600
# 4      16.067593  104.087807      335.17  0.49   0.49  2013/02/12       548
# ...          ...         ...         ...   ...    ...         ...       ...
# 61028  18.219433  103.938828      306.11  0.39   0.36  2013/04/11      1830
# 61029  18.225517  103.932045      302.50  0.39   0.36  2013/04/11      1830
# 61030  18.284437  103.975548      333.73  0.38   0.36  2013/04/21       612
# 61031  18.321087  103.646065      339.35  0.38   0.36  2013/02/16       612
# 61032  18.308784  103.654938      331.85  0.41   0.37  2013/11/26       612
#
# ...

# %%
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61033 entries, 0 to 61032
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   latitude    61033 non-null  float64
#  1   longitude   61033 non-null  float64
#  2   brightness  61033 non-null  float64
#  3   scan        61033 non-null  float64
#  4   track       61033 non-null  float64
#  5   acq_date    61033 non-null  object
#  6   acq_time    61033 non-null  int64
#  7   satellite   61033 non-null  object
#  8   instrument  61033 non-null  object
#  9   confidence  61033 non-null  object
#  10  version     61033 non-null  int64
#  11  bright_t31  61033 non-null  float64
#  12  frp         61033 non-null  float64
#  13  daynight    61033 non-null  object
#  14  type        61033 non-null  int64
#  15  Year        61033 non-null  int64
#  16  TAM_NAM_T   61033 non-null  object
#  17  AMPHOE_T    61033 non-null  object
#  18  AMPHOE_E    61033 non-null  object
# ...

# %%
print (df['Year'].value_counts())
# Out:
# 2022    15126
# Name: Year, dtype: int64

# %% [markdown]
# concat ทุกไฟล์ใน folder **ควรแน่ใจว่าไม่มีไฟล์อื่นๆใน folder**

# %%
#import pandas as pd
import os
import glob

# Define the path to the folder containing your CSV files
folder_path = '/content/drive/My Drive/PM_esan/Fire_Source_2012-2023Nov/03_Yearly_ADM_LU'  # Replace with your folder path
os.chdir(folder_path)

# Create a list of all CSV files in the folder
file_list = glob.glob('*.csv')

# Initialize an empty list to store DataFrames
dfs = []

# Loop through the files, read each file as a DataFrame, and append it to the list
for file in file_list:
    df = pd.read_csv(file)
    dfs.append(df)

# Concatenate all DataFrames in the list
combined_df = pd.concat(dfs, ignore_index=True)

# Display the first few rows of the combined DataFrame
combined_df.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0  16.04633  104.05120      312.16  0.42   0.38  2023/02/28      1849
# 1  16.01995  104.05153      302.58  0.66   0.73  2023/03/03      1934
# 2  16.05333  104.08307      348.88  0.43   0.38  2023/03/10       631
# 3  16.02009  104.09893      336.05  0.34   0.56  2023/03/30       657
# 4  16.02532  104.09833      356.00  0.34   0.56  2023/03/30       657
#
#   satellite instrument confidence  ... daynight  type  Year TAM_NAM_T  \
# 0         N      VIIRS          n  ...        N   NaN  2023  ต.ภูเงิน
# 1         N      VIIRS          n  ...        N   NaN  2023  ต.ภูเงิน
# 2         N      VIIRS          n  ...        D   NaN  2023  ต.ภูเงิน
# 3         N      VIIRS          n  ...        D   NaN  2023  ต.ภูเงิน
# 4         N      VIIRS          n  ...        D   NaN  2023  ต.ภูเงิน
#
#     AMPHOE_T          AMPHOE_E PROV_NAM_T PROV_NAM_E LUL1_CODE LUL2_CODE
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486962 entries, 0 to 486961
# Data columns (total 23 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   latitude    486962 non-null  float64
#  1   longitude   486962 non-null  float64
#  2   brightness  486962 non-null  float64
#  3   scan        486962 non-null  float64
#  4   track       486962 non-null  float64
#  5   acq_date    486962 non-null  object
#  6   acq_time    486962 non-null  int64
#  7   satellite   486962 non-null  object
#  8   instrument  486962 non-null  object
#  9   confidence  486962 non-null  object
#  10  version     486962 non-null  object
#  11  bright_t31  486962 non-null  float64
#  12  frp         486962 non-null  float64
#  13  daynight    486962 non-null  object
#  14  type        453647 non-null  float64
#  15  Year        486962 non-null  int64
#  16  TAM_NAM_T   486962 non-null  object
#  17  AMPHOE_T    486962 non-null  object
# ...

# %%
combined_df
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0       16.04633  104.05120      312.16  0.42   0.38  2023/02/28      1849
# 1       16.01995  104.05153      302.58  0.66   0.73  2023/03/03      1934
# 2       16.05333  104.08307      348.88  0.43   0.38  2023/03/10       631
# 3       16.02009  104.09893      336.05  0.34   0.56  2023/03/30       657
# 4       16.02532  104.09833      356.00  0.34   0.56  2023/03/30       657
# ...          ...        ...         ...   ...    ...         ...       ...
# 486957  18.22189  103.71188      301.16  0.45   0.39  2022/12/15      1855
# 486958  18.22325  103.70860      308.40  0.40   0.37  2022/12/16      1836
# 486959  18.22201  103.71094      309.61  0.55   0.42  2022/12/20      1902
# 486960  18.22198  103.70915      311.11  0.55   0.42  2022/12/20      1902
# 486961  18.27301  103.34790      330.60  0.39   0.36  2022/03/18       618
#
#        satellite instrument confidence  ... daynight  type  Year  \
# ...

# %%
print (combined_df['Year'].value_counts())
# Out:
# 2016    61869
# 2013    61033
# 2019    56930
# 2015    51020
# 2020    43311
# 2014    43303
# 2018    34832
# 2012    32288
# 2017    32063
# 2023    31683
# 2021    23504
# 2022    15126
# Name: Year, dtype: int64

# %%
print (combined_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486962 entries, 0 to 486961
# Data columns (total 23 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   latitude    486962 non-null  float64
#  1   longitude   486962 non-null  float64
#  2   brightness  486962 non-null  float64
#  3   scan        486962 non-null  float64
#  4   track       486962 non-null  float64
#  5   acq_date    486962 non-null  object
#  6   acq_time    486962 non-null  int64
#  7   satellite   486962 non-null  object
#  8   instrument  486962 non-null  object
#  9   confidence  486962 non-null  object
#  10  version     486962 non-null  object
#  11  bright_t31  486962 non-null  float64
#  12  frp         486962 non-null  float64
#  13  daynight    486962 non-null  object
#  14  type        453647 non-null  float64
#  15  Year        486962 non-null  int64
#  16  TAM_NAM_T   486962 non-null  object
#  17  AMPHOE_T    486962 non-null  object
# ...

# %%
combined_df.drop('type',axis = 1,inplace = True)

# %%
combined_df.columns
# Out:
# Index(['latitude', 'longitude', 'brightness', 'scan', 'track', 'acq_date',
#        'acq_time', 'satellite', 'instrument', 'confidence', 'version',
#        'bright_t31', 'frp', 'daynight', 'Year', 'TAM_NAM_T', 'AMPHOE_T',
#        'AMPHOE_E', 'PROV_NAM_T', 'PROV_NAM_E', 'LUL1_CODE', 'LUL2_CODE'],
#       dtype='object')

# %%
# Export the DataFrame to a CSV file
combined_df.to_csv('combined_data.csv', index=False)
